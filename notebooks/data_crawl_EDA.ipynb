# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
bible_source = 'https://www.gutenberg.org/files/10/10-h/10-h.htm'
r = requests.get(bible_source)
soup = BeautifulSoup(r.content, 'html5lib')

verses = [i.contents[0] for i in soup.find_all('p')]
chapter_verse = [i.split(' ')[0] for i in verses]

for i, cv in enumerate(chapter_verse):
    if len(cv.split(':')) < 2:
        verses.pop(i)
        chapter_verse.pop(i)
for i, cv in enumerate(chapter_verse):
    if len(cv.split(':')) < 2:
        verses.pop(i)
        chapter_verse.pop(i)
        
chapter_num = [i.split(':')[0] for i in chapter_verse]
verse_num = [i.split(':')[1] for i in chapter_verse]

verses = [" ".join(i.split(' ')[1:]) for i in verses]

# %%
bible = pd.DataFrame(zip(chapter_num, verse_num, verses), columns = ['chapter_num', 'verse_num', 'verse'])

# %%
bible
# Out:
#       chapter_num verse_num                                              verse
# 0               1         1  In the beginning God created the heaven and th...
# 1               1         2  And the earth was without form, and void; and ...
# 2               1         3  And God said, Let there be light: and there wa...
# 3               1         4  And God saw the light, that it was good: and G...
# 4               1         5  And God called the light Day, and the darkness...
# ...           ...       ...                                                ...
# 24399          22        16  I Jesus have sent mine angel to testify unto y...
# 24400          22        17  And the Spirit and the bride say, Come. And le...
# 24401          22        18  For I testify unto every man that heareth the ...
# 24402          22        20  He which testifieth these things saith, Surely...
# 24403          22        21  The grace of our Lord Jesus Christ be with you...
#
# [24404 rows x 3 columns]
